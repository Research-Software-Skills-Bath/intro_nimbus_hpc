# %% [markdown]
# DO NOT REMOVE THIS CELL!
#
# You can replace the existing template by modifying the next cell. When the notebook is rendered the following will happen:
#
# All the cells below will be inserted at the top of all the rendered notebooks as is.

# %% [markdown]
# <div style="
#   background-color: #6f8895;
#   padding: 25px 20px;
#   margin-bottom: 15px;
# ">
#   <h1 style="margin: 0; color: #111;">University of Bath</h1>
#   <h2 style="margin: 5px 0 0 0; color: #111;">Research Computing Team (DDaT)</h2>
#   <h3 style="margin: 5px 0 0 0; color: #222;">Nimbus HPC Documentation</h3>
# </div>
#
# <div style="
#   margin: 10px 0 25px 0;
#   padding: 10px 0;
#   border-bottom: 1px solid #ccc;
#   font-size: 15px;
# ">
#
#   <a href="00_schedule.html" style="margin-right: 18px;">Schedule</a>
#   <a href="01_introHPC.html" style="margin-right: 18px;">Intro HPC</a>
#   <a href="02_access_cloud.html" style="margin-right: 18px;">Access</a>
#   <a href="03_infrastructure.html" style="margin-right: 18px;">Infrastructure</a>
#   <a href="04_slurm.html" style="margin-right: 18px;">Slurm</a>
#   <a href="05_compute_instances.html" style="margin-right: 18px;">Compute</a>
#   <a href="06_software.html" style="margin-right: 18px;">Software</a>
#   <a href="07_storage.html" style="margin-right: 18px;">Storage</a>
#   <a href="08_transferring_files.html" style="margin-right: 18px;">Transfer</a>
#   <a href="09_running_jobs.html">Jobs</a>
#
# </div>
